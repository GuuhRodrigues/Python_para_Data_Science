# %% [markdown]
# ## Desafio 1 : trabalhando em outros contextos

# %% [markdown]
# ### Projeto desafio 1: vendas online
# ##### O objetivo desse projeto é realizar uma análise dos resultados de um evento com os clientes de uma empresa de vendas online. Foi coletado um conjunto de dados que contém os clientes que mais gastaram com produtos dentro de 5 dias de vendas, que é o período de duração do evento. Essa análise vai identificar o cliente com a maior compra na semana, que irá receber um prêmio da loja, e posteriormente, ela pode ajudar a empresa a criar novas estratégias para atrair mais clientes.
#
# ##### A base de dados utilizada nessa análise é a dados_vendas_clientes.json e contém informações importantes sobre os clientes como, o nome de cadastro do cliente, o valor total pago na compra e o dia da compra.
#
# ##### Sabendo essas informações, o desafio do projeto 1: vendas online será abrir a base de dados com Pandas e aplicar o json_normalize.

# %%
import pandas as pd

dados = pd.read_json('C:/Users/Guuh/Downloads/Python para Data Science/Exercicios/7-Pandas-transformacao-manipulacao-dados/dados_vendas_clientes.json')
dados
# Out:
#                                         dados_vendas
# 0  {'Data de venda': '06/06/2022', 'Cliente': ['@...
# 1  {'Data de venda': '07/06/2022', 'Cliente': ['I...
# 2  {'Data de venda': '08/06/2022', 'Cliente': ['I...
# 3  {'Data de venda': '09/06/2022', 'Cliente': ['J...
# 4  {'Data de venda': '10/06/2022', 'Cliente': ['M...

# %%
dados = pd.json_normalize(dados['dados_vendas'])
dados
# Out:
#   Data de venda                                            Cliente  \
# 0    06/06/2022  [@ANA _LUCIA 321, DieGO ARMANDIU 210, DieGO AR...
# 1    07/06/2022  [Isabely JOanes 738, Isabely JOanes 738, Isabe...
# 2    08/06/2022  [Isabely JOanes 738, JOãO Gabriel 671, Julya m...
# 3    09/06/2022  [Julya meireles 914, MaRIA Julia 444, MaRIA Ju...
# 4    10/06/2022  [MaRIA Julia 444, PEDRO PASCO 812, Paulo castr...
#
#                                 Valor da compra
# 0    [R$ 836,5, R$ 573,33, R$ 392,8, R$ 512,34]
# 1  [R$ 825,31, R$ 168,07, R$ 339,18, R$ 314,69]
# 2  [R$ 682,05, R$ 386,34, R$ 622,65, R$ 630,79]
# 3   [R$ 390,3, R$ 759,16, R$ 334,47, R$ 678,78]
# 4  [R$ 314,24, R$ 311,15, R$ 899,16, R$ 885,24]

# %% [markdown]
# ### Projeto desafio 2: administração de condomínios
# ##### A administração de condomínios é uma tarefa que requer muita atenção e organização. Entre as diversas responsabilidades da gestão está o recebimento dos aluguéis dos locatários. Para garantir uma boa saúde financeira do empreendimento, é fundamental que esses pagamentos sejam feitos de forma regular e pontual. No entanto, sabemos que nem sempre isso acontece.
#
# ##### Pensando nisso, proponho um desafio de tratamento de dados com o objetivo de analisar o atraso no pagamento de aluguéis no condomínio de alguns moradores. Disponibilizo a base de dados dados_locacao_imoveis.json, que contém informações sobre o apartamento dos locatários, o dia acordado para o pagamento do aluguel, o dia da efetivação do pagamento de aluguel e o valor do aluguel.
#
# ##### Com essas informações, o desafio do projeto 2: administração de condomínios será similar ao desafio do projeto 1, abrir a base de dados com Pandas e aplicar o json_normalize no DataFrame.

# %%
import pandas as pd

dados2= pd.read_json('C:/Users/Guuh/Downloads/Python para Data Science/Exercicios/7-Pandas-transformacao-manipulacao-dados/dados_locacao_imoveis.json')
dados2
# Out:
#                                         dados_locacao
# 0   {'apartamento': 'A101 (blocoAP)', 'datas_combi...
# 1   {'apartamento': 'A102 (blocoAP)', 'datas_combi...
# 2   {'apartamento': 'B201 (blocoAP)', 'datas_combi...
# 3   {'apartamento': 'B202 (blocoAP)', 'datas_combi...
# 4   {'apartamento': 'C301 (blocoAP)', 'datas_combi...
# 5   {'apartamento': 'C302 (blocoAP)', 'datas_combi...
# 6   {'apartamento': 'D401 (blocoAP)', 'datas_combi...
# 7   {'apartamento': 'D402 (blocoAP)', 'datas_combi...
# 8   {'apartamento': 'E501 (blocoAP)', 'datas_combi...
# 9   {'apartamento': 'E502 (blocoAP)', 'datas_combi...
# 10  {'apartamento': 'F601 (blocoAP)', 'datas_combi...
# 11  {'apartamento': 'F602 (blocoAP)', 'datas_combi...
# 12  {'apartamento': 'G701 (blocoAP)', 'datas_combi...
# 13  {'apartamento': 'G702 (blocoAP)', 'datas_combi...
# 14  {'apartamento': 'H801 (blocoAP)', 'datas_combi...

# %%
dados2 = pd.json_normalize(dados2['dados_locacao'])
dados2
# Out:
#        apartamento datas_combinadas_pagamento        datas_de_pagamento  \
# 0   A101 (blocoAP)   [01/06/2022, 01/07/2022]  [05/06/2022, 03/07/2022]
# 1   A102 (blocoAP)   [02/06/2022, 02/07/2022]  [02/06/2022, 06/07/2022]
# 2   B201 (blocoAP)   [03/06/2022, 03/07/2022]  [07/06/2022, 03/07/2022]
# 3   B202 (blocoAP)   [04/06/2022, 04/07/2022]  [07/06/2022, 05/07/2022]
# 4   C301 (blocoAP)   [05/06/2022, 05/07/2022]  [10/06/2022, 09/07/2022]
# 5   C302 (blocoAP)   [06/06/2022, 06/07/2022]  [08/06/2022, 12/07/2022]
# 6   D401 (blocoAP)   [07/06/2022, 07/07/2022]  [07/06/2022, 09/07/2022]
# 7   D402 (blocoAP)   [08/06/2022, 08/07/2022]  [10/06/2022, 14/07/2022]
# 8   E501 (blocoAP)   [09/06/2022, 09/07/2022]  [10/06/2022, 09/07/2022]
# 9   E502 (blocoAP)   [10/06/2022, 10/07/2022]  [16/06/2022, 12/07/2022]
# 10  F601 (blocoAP)   [11/06/2022, 11/07/2022]  [17/06/2022, 13/07/2022]
# 11  F602 (blocoAP)   [12/06/2022, 12/07/2022]  [15/06/2022, 12/07/2022]
# 12  G701 (blocoAP)   [13/06/2022, 13/07/2022]  [19/06/2022, 20/07/2022]
# 13  G702 (blocoAP)   [14/06/2022, 14/07/2022]  [15/06/2022, 17/07/2022]
# 14  H801 (blocoAP)   [15/06/2022, 15/07/2022]  [18/06/2022, 16/07/2022]
#
#                        valor_aluguel
# 0   [$ 1000,0 reais, $ 2500,0 reais]
# 1   [$ 1100,0 reais, $ 2600,0 reais]
# 2   [$ 1200,0 reais, $ 2700,0 reais]
# 3   [$ 1300,0 reais, $ 2800,0 reais]
# 4   [$ 1400,0 reais, $ 2900,0 reais]
# 5   [$ 1500,0 reais, $ 1200,0 reais]
# 6   [$ 1600,0 reais, $ 1300,0 reais]
# 7   [$ 1700,0 reais, $ 1400,0 reais]
# 8   [$ 1800,0 reais, $ 1500,0 reais]
# 9   [$ 1900,0 reais, $ 1600,0 reais]
# 10  [$ 2000,0 reais, $ 1000,0 reais]
# 11  [$ 2100,0 reais, $ 1100,0 reais]
# 12  [$ 2200,0 reais, $ 1200,0 reais]
# 13  [$ 2300,0 reais, $ 2100,0 reais]
# 14  [$ 2400,0 reais, $ 2200,0 reais]

# %% [markdown]
# ## Desafio 2 : trabalhando em outros contextos

# %% [markdown]
# ### Projeto desafio 1: vendas online
# ##### Lemos a base de dados no desafio anterior, agora podemos avançar nas transformações desses dados. Então, o novo desafio do projeto 1 será dividido em algumas metas:
#
# ##### -Remover os dados em listas dentro do DataFrame;
# ##### -Verificar os tipos de dados;
# ##### -Identificar colunas numéricas;
# ##### -Transformar a coluna numérica para o tipo numérico.

# %%
import numpy as np
dados
# Out:
#   Data de venda                                            Cliente  \
# 0    06/06/2022  [@ANA _LUCIA 321, DieGO ARMANDIU 210, DieGO AR...
# 1    07/06/2022  [Isabely JOanes 738, Isabely JOanes 738, Isabe...
# 2    08/06/2022  [Isabely JOanes 738, JOãO Gabriel 671, Julya m...
# 3    09/06/2022  [Julya meireles 914, MaRIA Julia 444, MaRIA Ju...
# 4    10/06/2022  [MaRIA Julia 444, PEDRO PASCO 812, Paulo castr...
#
#                                 Valor da compra
# 0    [R$ 836,5, R$ 573,33, R$ 392,8, R$ 512,34]
# 1  [R$ 825,31, R$ 168,07, R$ 339,18, R$ 314,69]
# 2  [R$ 682,05, R$ 386,34, R$ 622,65, R$ 630,79]
# 3   [R$ 390,3, R$ 759,16, R$ 334,47, R$ 678,78]
# 4  [R$ 314,24, R$ 311,15, R$ 899,16, R$ 885,24]

# %%
colunas = list(dados.columns[1:])
colunas
# Out:
# ['Cliente', 'Valor da compra']

# %%
#Remover os dados em listas dentro do DataFrame e reseta os indices;
dados = dados.explode(colunas)
dados.reset_index(inplace=True, drop=True) 
dados
# Out:
#    Data de venda             Cliente Valor da compra
# 0     06/06/2022     @ANA _LUCIA 321        R$ 836,5
# 1     06/06/2022  DieGO ARMANDIU 210       R$ 573,33
# 2     06/06/2022  DieGO ARMANDIU 210        R$ 392,8
# 3     06/06/2022  DieGO ARMANDIU 210       R$ 512,34
# 4     07/06/2022  Isabely JOanes 738       R$ 825,31
# 5     07/06/2022  Isabely JOanes 738       R$ 168,07
# 6     07/06/2022  Isabely JOanes 738       R$ 339,18
# 7     07/06/2022  Isabely JOanes 738       R$ 314,69
# 8     08/06/2022  Isabely JOanes 738       R$ 682,05
# 9     08/06/2022    JOãO Gabriel 671       R$ 386,34
# 10    08/06/2022  Julya meireles 914       R$ 622,65
# 11    08/06/2022  Julya meireles 914       R$ 630,79
# 12    09/06/2022  Julya meireles 914        R$ 390,3
# 13    09/06/2022     MaRIA Julia 444       R$ 759,16
# 14    09/06/2022     MaRIA Julia 444       R$ 334,47
# 15    09/06/2022     MaRIA Julia 444       R$ 678,78
# 16    10/06/2022     MaRIA Julia 444       R$ 314,24
# 17    10/06/2022     PEDRO PASCO 812       R$ 311,15
# 18    10/06/2022    Paulo castro 481       R$ 899,16
# 19    10/06/2022   Thiago fritzz 883       R$ 885,24

# %%
#Verificar os tipos de dados;
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Data de venda    20 non-null     object
#  1   Cliente          20 non-null     object
#  2   Valor da compra  20 non-null     object
# dtypes: object(3)
# memory usage: 608.0+ bytes

# %%
dados['Valor da compra'] = dados['Valor da compra'].apply(lambda x: x.replace('R$', '').replace(',', '.').strip())
dados
# Out:
#    Data de venda             Cliente Valor da compra
# 0     06/06/2022     @ANA _LUCIA 321           836.5
# 1     06/06/2022  DieGO ARMANDIU 210          573.33
# 2     06/06/2022  DieGO ARMANDIU 210           392.8
# 3     06/06/2022  DieGO ARMANDIU 210          512.34
# 4     07/06/2022  Isabely JOanes 738          825.31
# 5     07/06/2022  Isabely JOanes 738          168.07
# 6     07/06/2022  Isabely JOanes 738          339.18
# 7     07/06/2022  Isabely JOanes 738          314.69
# 8     08/06/2022  Isabely JOanes 738          682.05
# 9     08/06/2022    JOãO Gabriel 671          386.34
# 10    08/06/2022  Julya meireles 914          622.65
# 11    08/06/2022  Julya meireles 914          630.79
# 12    09/06/2022  Julya meireles 914           390.3
# 13    09/06/2022     MaRIA Julia 444          759.16
# 14    09/06/2022     MaRIA Julia 444          334.47
# 15    09/06/2022     MaRIA Julia 444          678.78
# 16    10/06/2022     MaRIA Julia 444          314.24
# 17    10/06/2022     PEDRO PASCO 812          311.15
# 18    10/06/2022    Paulo castro 481          899.16
# 19    10/06/2022   Thiago fritzz 883          885.24

# %%
dados['Valor da compra'] = dados['Valor da compra'].astype(np.float64)
dados
# Out:
#    Data de venda             Cliente  Valor da compra
# 0     06/06/2022     @ANA _LUCIA 321           836.50
# 1     06/06/2022  DieGO ARMANDIU 210           573.33
# 2     06/06/2022  DieGO ARMANDIU 210           392.80
# 3     06/06/2022  DieGO ARMANDIU 210           512.34
# 4     07/06/2022  Isabely JOanes 738           825.31
# 5     07/06/2022  Isabely JOanes 738           168.07
# 6     07/06/2022  Isabely JOanes 738           339.18
# 7     07/06/2022  Isabely JOanes 738           314.69
# 8     08/06/2022  Isabely JOanes 738           682.05
# 9     08/06/2022    JOãO Gabriel 671           386.34
# 10    08/06/2022  Julya meireles 914           622.65
# 11    08/06/2022  Julya meireles 914           630.79
# 12    09/06/2022  Julya meireles 914           390.30
# 13    09/06/2022     MaRIA Julia 444           759.16
# 14    09/06/2022     MaRIA Julia 444           334.47
# 15    09/06/2022     MaRIA Julia 444           678.78
# 16    10/06/2022     MaRIA Julia 444           314.24
# 17    10/06/2022     PEDRO PASCO 812           311.15
# 18    10/06/2022    Paulo castro 481           899.16
# 19    10/06/2022   Thiago fritzz 883           885.24

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Data de venda    20 non-null     object
#  1   Cliente          20 non-null     object
#  2   Valor da compra  20 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 608.0+ bytes

# %% [markdown]
# ### Projeto desafio 2: administração de condomínios
# ##### Lemos a base de dados no desafio anterior, agora podemos avançar nas transformações desses dados. Então, da mesma forma que o projeto 1, o desafio do projeto 2 está listado em algumas metas:
#
# ##### -Remover os dados em listas dentro do DataFrame;
# ##### -Verificar os tipos de dados;
# ##### -Identificar colunas numéricas;
# ##### -Transformar a coluna numérica para o tipo numérico.

# %%
dados2
# Out:
#        apartamento datas_combinadas_pagamento        datas_de_pagamento  \
# 0   A101 (blocoAP)   [01/06/2022, 01/07/2022]  [05/06/2022, 03/07/2022]
# 1   A102 (blocoAP)   [02/06/2022, 02/07/2022]  [02/06/2022, 06/07/2022]
# 2   B201 (blocoAP)   [03/06/2022, 03/07/2022]  [07/06/2022, 03/07/2022]
# 3   B202 (blocoAP)   [04/06/2022, 04/07/2022]  [07/06/2022, 05/07/2022]
# 4   C301 (blocoAP)   [05/06/2022, 05/07/2022]  [10/06/2022, 09/07/2022]
# 5   C302 (blocoAP)   [06/06/2022, 06/07/2022]  [08/06/2022, 12/07/2022]
# 6   D401 (blocoAP)   [07/06/2022, 07/07/2022]  [07/06/2022, 09/07/2022]
# 7   D402 (blocoAP)   [08/06/2022, 08/07/2022]  [10/06/2022, 14/07/2022]
# 8   E501 (blocoAP)   [09/06/2022, 09/07/2022]  [10/06/2022, 09/07/2022]
# 9   E502 (blocoAP)   [10/06/2022, 10/07/2022]  [16/06/2022, 12/07/2022]
# 10  F601 (blocoAP)   [11/06/2022, 11/07/2022]  [17/06/2022, 13/07/2022]
# 11  F602 (blocoAP)   [12/06/2022, 12/07/2022]  [15/06/2022, 12/07/2022]
# 12  G701 (blocoAP)   [13/06/2022, 13/07/2022]  [19/06/2022, 20/07/2022]
# 13  G702 (blocoAP)   [14/06/2022, 14/07/2022]  [15/06/2022, 17/07/2022]
# 14  H801 (blocoAP)   [15/06/2022, 15/07/2022]  [18/06/2022, 16/07/2022]
#
#                        valor_aluguel
# 0   [$ 1000,0 reais, $ 2500,0 reais]
# 1   [$ 1100,0 reais, $ 2600,0 reais]
# 2   [$ 1200,0 reais, $ 2700,0 reais]
# 3   [$ 1300,0 reais, $ 2800,0 reais]
# 4   [$ 1400,0 reais, $ 2900,0 reais]
# 5   [$ 1500,0 reais, $ 1200,0 reais]
# 6   [$ 1600,0 reais, $ 1300,0 reais]
# 7   [$ 1700,0 reais, $ 1400,0 reais]
# 8   [$ 1800,0 reais, $ 1500,0 reais]
# 9   [$ 1900,0 reais, $ 1600,0 reais]
# 10  [$ 2000,0 reais, $ 1000,0 reais]
# 11  [$ 2100,0 reais, $ 1100,0 reais]
# 12  [$ 2200,0 reais, $ 1200,0 reais]
# 13  [$ 2300,0 reais, $ 2100,0 reais]
# 14  [$ 2400,0 reais, $ 2200,0 reais]

# %%
colunas2 = list(dados2.columns[1:])
colunas2
# Out:
# ['datas_combinadas_pagamento', 'datas_de_pagamento', 'valor_aluguel']

# %%
#Remover os dados em listas dentro do DataFrame;
dados2 = dados2.explode(colunas2)
dados2
# Out:
#        apartamento datas_combinadas_pagamento datas_de_pagamento  \
# 0   A101 (blocoAP)                 01/06/2022         05/06/2022
# 0   A101 (blocoAP)                 01/07/2022         03/07/2022
# 1   A102 (blocoAP)                 02/06/2022         02/06/2022
# 1   A102 (blocoAP)                 02/07/2022         06/07/2022
# 2   B201 (blocoAP)                 03/06/2022         07/06/2022
# 2   B201 (blocoAP)                 03/07/2022         03/07/2022
# 3   B202 (blocoAP)                 04/06/2022         07/06/2022
# 3   B202 (blocoAP)                 04/07/2022         05/07/2022
# 4   C301 (blocoAP)                 05/06/2022         10/06/2022
# 4   C301 (blocoAP)                 05/07/2022         09/07/2022
# 5   C302 (blocoAP)                 06/06/2022         08/06/2022
# 5   C302 (blocoAP)                 06/07/2022         12/07/2022
# 6   D401 (blocoAP)                 07/06/2022         07/06/2022
# 6   D401 (blocoAP)                 07/07/2022         09/07/2022
# 7   D402 (blocoAP)                 08/06/2022         10/06/2022
# 7   D402 (blocoAP)                 08/07/2022         14/07/2022
# 8   E501 (blocoAP)                 09/06/2022         10/06/2022
# 8   E501 (blocoAP)                 09/07/2022         09/07/2022
# 9   E502 (blocoAP)                 10/06/2022         16/06/2022
# 9   E502 (blocoAP)                 10/07/2022         12/07/2022
# 10  F601 (blocoAP)                 11/06/2022         17/06/2022
# 10  F601 (blocoAP)                 11/07/2022         13/07/2022
# 11  F602 (blocoAP)                 12/06/2022         15/06/2022
# 11  F602 (blocoAP)                 12/07/2022         12/07/2022
# 12  G701 (blocoAP)                 13/06/2022         19/06/2022
# 12  G701 (blocoAP)                 13/07/2022         20/07/2022
# 13  G702 (blocoAP)                 14/06/2022         15/06/2022
# 13  G702 (blocoAP)                 14/07/2022         17/07/2022
# 14  H801 (blocoAP)                 15/06/2022         18/06/2022
# 14  H801 (blocoAP)                 15/07/2022         16/07/2022
#
#      valor_aluguel
# 0   $ 1000,0 reais
# 0   $ 2500,0 reais
# 1   $ 1100,0 reais
# 1   $ 2600,0 reais
# 2   $ 1200,0 reais
# 2   $ 2700,0 reais
# 3   $ 1300,0 reais
# 3   $ 2800,0 reais
# 4   $ 1400,0 reais
# 4   $ 2900,0 reais
# 5   $ 1500,0 reais
# 5   $ 1200,0 reais
# 6   $ 1600,0 reais
# 6   $ 1300,0 reais
# 7   $ 1700,0 reais
# 7   $ 1400,0 reais
# 8   $ 1800,0 reais
# 8   $ 1500,0 reais
# 9   $ 1900,0 reais
# 9   $ 1600,0 reais
# 10  $ 2000,0 reais
# 10  $ 1000,0 reais
# 11  $ 2100,0 reais
# 11  $ 1100,0 reais
# 12  $ 2200,0 reais
# 12  $ 1200,0 reais
# 13  $ 2300,0 reais
# 13  $ 2100,0 reais
# 14  $ 2400,0 reais
# 14  $ 2200,0 reais

# %%
# resetando indice
dados2.reset_index(inplace=True, drop=True)
dados2
# Out:
#        apartamento datas_combinadas_pagamento datas_de_pagamento  \
# 0   A101 (blocoAP)                 01/06/2022         05/06/2022
# 1   A101 (blocoAP)                 01/07/2022         03/07/2022
# 2   A102 (blocoAP)                 02/06/2022         02/06/2022
# 3   A102 (blocoAP)                 02/07/2022         06/07/2022
# 4   B201 (blocoAP)                 03/06/2022         07/06/2022
# 5   B201 (blocoAP)                 03/07/2022         03/07/2022
# 6   B202 (blocoAP)                 04/06/2022         07/06/2022
# 7   B202 (blocoAP)                 04/07/2022         05/07/2022
# 8   C301 (blocoAP)                 05/06/2022         10/06/2022
# 9   C301 (blocoAP)                 05/07/2022         09/07/2022
# 10  C302 (blocoAP)                 06/06/2022         08/06/2022
# 11  C302 (blocoAP)                 06/07/2022         12/07/2022
# 12  D401 (blocoAP)                 07/06/2022         07/06/2022
# 13  D401 (blocoAP)                 07/07/2022         09/07/2022
# 14  D402 (blocoAP)                 08/06/2022         10/06/2022
# 15  D402 (blocoAP)                 08/07/2022         14/07/2022
# 16  E501 (blocoAP)                 09/06/2022         10/06/2022
# 17  E501 (blocoAP)                 09/07/2022         09/07/2022
# 18  E502 (blocoAP)                 10/06/2022         16/06/2022
# 19  E502 (blocoAP)                 10/07/2022         12/07/2022
# 20  F601 (blocoAP)                 11/06/2022         17/06/2022
# 21  F601 (blocoAP)                 11/07/2022         13/07/2022
# 22  F602 (blocoAP)                 12/06/2022         15/06/2022
# 23  F602 (blocoAP)                 12/07/2022         12/07/2022
# 24  G701 (blocoAP)                 13/06/2022         19/06/2022
# 25  G701 (blocoAP)                 13/07/2022         20/07/2022
# 26  G702 (blocoAP)                 14/06/2022         15/06/2022
# 27  G702 (blocoAP)                 14/07/2022         17/07/2022
# 28  H801 (blocoAP)                 15/06/2022         18/06/2022
# 29  H801 (blocoAP)                 15/07/2022         16/07/2022
#
#      valor_aluguel
# 0   $ 1000,0 reais
# 1   $ 2500,0 reais
# 2   $ 1100,0 reais
# 3   $ 2600,0 reais
# 4   $ 1200,0 reais
# 5   $ 2700,0 reais
# 6   $ 1300,0 reais
# 7   $ 2800,0 reais
# 8   $ 1400,0 reais
# 9   $ 2900,0 reais
# 10  $ 1500,0 reais
# 11  $ 1200,0 reais
# 12  $ 1600,0 reais
# 13  $ 1300,0 reais
# 14  $ 1700,0 reais
# 15  $ 1400,0 reais
# 16  $ 1800,0 reais
# 17  $ 1500,0 reais
# 18  $ 1900,0 reais
# 19  $ 1600,0 reais
# 20  $ 2000,0 reais
# 21  $ 1000,0 reais
# 22  $ 2100,0 reais
# 23  $ 1100,0 reais
# 24  $ 2200,0 reais
# 25  $ 1200,0 reais
# 26  $ 2300,0 reais
# 27  $ 2100,0 reais
# 28  $ 2400,0 reais
# 29  $ 2200,0 reais

# %%
dados2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 4 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   apartamento                 30 non-null     object
#  1   datas_combinadas_pagamento  30 non-null     object
#  2   datas_de_pagamento          30 non-null     object
#  3   valor_aluguel               30 non-null     object
# dtypes: object(4)
# memory usage: 1.1+ KB

# %%
dados2['valor_aluguel'] = dados2['valor_aluguel'].apply(lambda x: x.replace('$', '').replace(',', '.').replace('reais', '').strip())
dados2
# Out:
#        apartamento datas_combinadas_pagamento datas_de_pagamento valor_aluguel
# 0   A101 (blocoAP)                 01/06/2022         05/06/2022        1000.0
# 1   A101 (blocoAP)                 01/07/2022         03/07/2022        2500.0
# 2   A102 (blocoAP)                 02/06/2022         02/06/2022        1100.0
# 3   A102 (blocoAP)                 02/07/2022         06/07/2022        2600.0
# 4   B201 (blocoAP)                 03/06/2022         07/06/2022        1200.0
# 5   B201 (blocoAP)                 03/07/2022         03/07/2022        2700.0
# 6   B202 (blocoAP)                 04/06/2022         07/06/2022        1300.0
# 7   B202 (blocoAP)                 04/07/2022         05/07/2022        2800.0
# 8   C301 (blocoAP)                 05/06/2022         10/06/2022        1400.0
# 9   C301 (blocoAP)                 05/07/2022         09/07/2022        2900.0
# 10  C302 (blocoAP)                 06/06/2022         08/06/2022        1500.0
# 11  C302 (blocoAP)                 06/07/2022         12/07/2022        1200.0
# 12  D401 (blocoAP)                 07/06/2022         07/06/2022        1600.0
# 13  D401 (blocoAP)                 07/07/2022         09/07/2022        1300.0
# 14  D402 (blocoAP)                 08/06/2022         10/06/2022        1700.0
# 15  D402 (blocoAP)                 08/07/2022         14/07/2022        1400.0
# 16  E501 (blocoAP)                 09/06/2022         10/06/2022        1800.0
# 17  E501 (blocoAP)                 09/07/2022         09/07/2022        1500.0
# 18  E502 (blocoAP)                 10/06/2022         16/06/2022        1900.0
# 19  E502 (blocoAP)                 10/07/2022         12/07/2022        1600.0
# 20  F601 (blocoAP)                 11/06/2022         17/06/2022        2000.0
# 21  F601 (blocoAP)                 11/07/2022         13/07/2022        1000.0
# 22  F602 (blocoAP)                 12/06/2022         15/06/2022        2100.0
# 23  F602 (blocoAP)                 12/07/2022         12/07/2022        1100.0
# 24  G701 (blocoAP)                 13/06/2022         19/06/2022        2200.0
# 25  G701 (blocoAP)                 13/07/2022         20/07/2022        1200.0
# 26  G702 (blocoAP)                 14/06/2022         15/06/2022        2300.0
# 27  G702 (blocoAP)                 14/07/2022         17/07/2022        2100.0
# 28  H801 (blocoAP)                 15/06/2022         18/06/2022        2400.0
# 29  H801 (blocoAP)                 15/07/2022         16/07/2022        2200.0

# %%
dados2['valor_aluguel'] = dados2['valor_aluguel'].astype(np.float64)
dados2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 4 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   apartamento                 30 non-null     object
#  1   datas_combinadas_pagamento  30 non-null     object
#  2   datas_de_pagamento          30 non-null     object
#  3   valor_aluguel               30 non-null     float64
# dtypes: float64(1), object(3)
# memory usage: 1.1+ KB

# %% [markdown]
# ## Desafio 3 Extra: faça você mesmo OBS: RESOLVIDO NO NOTEBOOK DO CURSO 7

# %% [markdown]
# ## Desafio 3 : trabalhando em outros contextos

# %% [markdown]
# ### Projeto desafio 1: vendas online
# ##### Na etapa 2, trabalhamos na transformação dos dados numéricos. Agora, podemos trabalhar com valores textuais.
#
# ##### Devido a uma instabilidade no site da empresa, tivemos problemas com os nomes dos clientes durante o salvamento. Isso resultou em uma coluna de nomes de clientes com uma mistura de letras, maiúsculas e minúsculas, números e outros caracteres.
#
# ##### Sabendo disso, manipule os textos presentes na coluna Cliente para que seja obtido como resultado os nomes dos clientes em letras minúsculas, com a ausência de caracteres especiais ou números.

# %%
dados
# Out:
#    Data de venda             Cliente  Valor da compra
# 0     06/06/2022     @ANA _LUCIA 321           836.50
# 1     06/06/2022  DieGO ARMANDIU 210           573.33
# 2     06/06/2022  DieGO ARMANDIU 210           392.80
# 3     06/06/2022  DieGO ARMANDIU 210           512.34
# 4     07/06/2022  Isabely JOanes 738           825.31
# 5     07/06/2022  Isabely JOanes 738           168.07
# 6     07/06/2022  Isabely JOanes 738           339.18
# 7     07/06/2022  Isabely JOanes 738           314.69
# 8     08/06/2022  Isabely JOanes 738           682.05
# 9     08/06/2022    JOãO Gabriel 671           386.34
# 10    08/06/2022  Julya meireles 914           622.65
# 11    08/06/2022  Julya meireles 914           630.79
# 12    09/06/2022  Julya meireles 914           390.30
# 13    09/06/2022     MaRIA Julia 444           759.16
# 14    09/06/2022     MaRIA Julia 444           334.47
# 15    09/06/2022     MaRIA Julia 444           678.78
# 16    10/06/2022     MaRIA Julia 444           314.24
# 17    10/06/2022     PEDRO PASCO 812           311.15
# 18    10/06/2022    Paulo castro 481           899.16
# 19    10/06/2022   Thiago fritzz 883           885.24

# %%
dados['Cliente'] = dados['Cliente'].str.lower().replace('[^a-zA-Z\-\']',' ',regex=True).replace('  ', ' ', regex=True).replace('\d', ' ', regex=True)
dados['Cliente']
# Out:
# 0          ana lucia
# 1     diego armandiu
# 2     diego armandiu
# 3     diego armandiu
# 4     isabely joanes
# 5     isabely joanes
# 6     isabely joanes
# 7     isabely joanes
# 8     isabely joanes
# 9       jo o gabriel
# 10    julya meireles
# 11    julya meireles
# 12    julya meireles
# 13       maria julia
# 14       maria julia
# 15       maria julia
# 16       maria julia
# 17       pedro pasco
# 18      paulo castro
# 19     thiago fritzz
# Name: Cliente, dtype: object

# %% [markdown]
# ### Projeto desafio 2: administração de condomínios
# ##### Na etapa 2, trabalhamos na transformação dos dados numéricos. Agora, podemos trabalhar com valores textuais.
#
# ##### Buscando explicar a organização da identificação dos apartamentos, durante a criação do conjunto de dados, foi adicionado o texto (blocoAP). Esse texto informa que os nomes dos apartamentos estão organizados com a letra do bloco seguida do número do apartamento. No entanto, isso não traz nenhuma informação para nossos dados, sendo interessante realizar a remoção desse texto no conjunto de dados.
#
# ##### Com isso, manipule os textos na coluna apartamento para remover o texto (blocoAP) do DataFrame.

# %%
dados2
# Out:
#        apartamento datas_combinadas_pagamento datas_de_pagamento  \
# 0   A101 (blocoAP)                 01/06/2022         05/06/2022
# 1   A101 (blocoAP)                 01/07/2022         03/07/2022
# 2   A102 (blocoAP)                 02/06/2022         02/06/2022
# 3   A102 (blocoAP)                 02/07/2022         06/07/2022
# 4   B201 (blocoAP)                 03/06/2022         07/06/2022
# 5   B201 (blocoAP)                 03/07/2022         03/07/2022
# 6   B202 (blocoAP)                 04/06/2022         07/06/2022
# 7   B202 (blocoAP)                 04/07/2022         05/07/2022
# 8   C301 (blocoAP)                 05/06/2022         10/06/2022
# 9   C301 (blocoAP)                 05/07/2022         09/07/2022
# 10  C302 (blocoAP)                 06/06/2022         08/06/2022
# 11  C302 (blocoAP)                 06/07/2022         12/07/2022
# 12  D401 (blocoAP)                 07/06/2022         07/06/2022
# 13  D401 (blocoAP)                 07/07/2022         09/07/2022
# 14  D402 (blocoAP)                 08/06/2022         10/06/2022
# 15  D402 (blocoAP)                 08/07/2022         14/07/2022
# 16  E501 (blocoAP)                 09/06/2022         10/06/2022
# 17  E501 (blocoAP)                 09/07/2022         09/07/2022
# 18  E502 (blocoAP)                 10/06/2022         16/06/2022
# 19  E502 (blocoAP)                 10/07/2022         12/07/2022
# 20  F601 (blocoAP)                 11/06/2022         17/06/2022
# 21  F601 (blocoAP)                 11/07/2022         13/07/2022
# 22  F602 (blocoAP)                 12/06/2022         15/06/2022
# 23  F602 (blocoAP)                 12/07/2022         12/07/2022
# 24  G701 (blocoAP)                 13/06/2022         19/06/2022
# 25  G701 (blocoAP)                 13/07/2022         20/07/2022
# 26  G702 (blocoAP)                 14/06/2022         15/06/2022
# 27  G702 (blocoAP)                 14/07/2022         17/07/2022
# 28  H801 (blocoAP)                 15/06/2022         18/06/2022
# 29  H801 (blocoAP)                 15/07/2022         16/07/2022
#
#     valor_aluguel
# 0          1000.0
# 1          2500.0
# 2          1100.0
# 3          2600.0
# 4          1200.0
# 5          2700.0
# 6          1300.0
# 7          2800.0
# 8          1400.0
# 9          2900.0
# 10         1500.0
# 11         1200.0
# 12         1600.0
# 13         1300.0
# 14         1700.0
# 15         1400.0
# 16         1800.0
# 17         1500.0
# 18         1900.0
# 19         1600.0
# 20         2000.0
# 21         1000.0
# 22         2100.0
# 23         1100.0
# 24         2200.0
# 25         1200.0
# 26         2300.0
# 27         2100.0
# 28         2400.0
# 29         2200.0

# %%
dados2['apartamento'] = dados2['apartamento'].str.replace('blocoAP', '', regex=True).replace('\(\)', '', regex=True)

# %%
dados2.head()
# Out:
#   apartamento datas_combinadas_pagamento datas_de_pagamento  valor_aluguel
# 0       A101                  01/06/2022         05/06/2022         1000.0
# 1       A101                  01/07/2022         03/07/2022         2500.0
# 2       A102                  02/06/2022         02/06/2022         1100.0
# 3       A102                  02/07/2022         06/07/2022         2600.0
# 4       B201                  03/06/2022         07/06/2022         1200.0

# %% [markdown]
# ## Desafio 4 Extra 2 : faça você mesmo OBS: RESOLVIDO NO NOTEBOOK DO CURSO 7

# %% [markdown]
# ## Desafio 4 : trabalhando em outros contextos

# %% [markdown]
# ### Projeto desafio 1: vendas online
# ##### Nas etapas anteriores, já trabalhamos com vários tipos de dados, agora podemos trabalhar com os dados de tempo.
#
# ##### Na coluna Data de venda, temos datas em formato 'dia/mês/ano' (dd/mm/AAAA). Transforme esses dados para o tipo datetime e busque uma forma de visualização de subconjunto que possa contribuir no objetivo do contexto que os dados estão inseridos.
#
# ##### Se você não lembra o problema do projeto desafio 1, vou deixar abaixo o texto da situação para facilitar o encontro da informação:
#
# ##### O objetivo desse projeto é realizar uma análise dos resultados de um evento com os clientes de uma empresa de vendas online. Foi coletado um conjunto de dados que contém os clientes que mais gastaram com produtos dentro de 5 dias de vendas, que é o período de duração do evento. Essa análise vai identificar o cliente com a maior compra na semana, que irá receber um prêmio da loja, e posteriormente, ela pode ajudar a empresa a criar novas estratégias para atrair mais clientes.

# %%
dados
# Out:
#    Data de venda           Cliente  Valor da compra
# 0     06/06/2022       ana lucia             836.50
# 1     06/06/2022  diego armandiu             573.33
# 2     06/06/2022  diego armandiu             392.80
# 3     06/06/2022  diego armandiu             512.34
# 4     07/06/2022  isabely joanes             825.31
# 5     07/06/2022  isabely joanes             168.07
# 6     07/06/2022  isabely joanes             339.18
# 7     07/06/2022  isabely joanes             314.69
# 8     08/06/2022  isabely joanes             682.05
# 9     08/06/2022    jo o gabriel             386.34
# 10    08/06/2022  julya meireles             622.65
# 11    08/06/2022  julya meireles             630.79
# 12    09/06/2022  julya meireles             390.30
# 13    09/06/2022     maria julia             759.16
# 14    09/06/2022     maria julia             334.47
# 15    09/06/2022     maria julia             678.78
# 16    10/06/2022     maria julia             314.24
# 17    10/06/2022     pedro pasco             311.15
# 18    10/06/2022    paulo castro             899.16
# 19    10/06/2022   thiago fritzz             885.24

# %%
dados['Data de venda'] = pd.to_datetime(dados['Data de venda'])

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Data de venda    20 non-null     datetime64[ns]
#  1   Cliente          20 non-null     object
#  2   Valor da compra  20 non-null     float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 608.0+ bytes

# %%
#atividade_valor_emissao_MG = df_emissoes_por_ano.loc[df_emissoes_por_ano['Estado'] == 'MG'].groupby('Nível 1 - Setor')['Emissão'].max().reset_index()
cliente_maior_compra = dados.loc[(dados['Data de venda'] >= dados['Data de venda'].min()) & (dados['Data de venda'] <= dados['Data de venda'].max())].groupby('Cliente')['Valor da compra'].sum()
cliente_maior_compra = cliente_maior_compra.idxmax()
cliente_maior_compra.title()
# Out:
# 'Isabely Joanes  '

# %% [markdown]
# ### Projeto desafio 2: administração de condomínios
# ##### Assim como no projeto desafio 1, trabalhamos com todas as colunas exceto as que envolvem datas.
#
# ##### Nas colunas datas_de_pagamento e datas_combinadas_pagamento, temos datas em formato 'dia/mês/ano' (dd/mm/AAAA). Transforme esses dados para o tipo datetime e busque uma forma de visualização de subconjunto que possa contribuir no objetivo do contexto que os dados estão inseridos.
#
# ##### Se você não lembra o problema do projeto desafio 2, vou deixar abaixo o texto da situação para facilitar o encontro da informação:
#
# ##### A administração de condomínios é uma tarefa que requer muita atenção e organização. Entre as diversas responsabilidades da gestão está o recebimento dos aluguéis dos locatários. Para garantir uma boa saúde financeira do empreendimento, é fundamental que esses pagamentos sejam feitos de forma regular e pontual. No entanto, sabemos que nem sempre isso acontece. Pensando nisso, proponho um desafio de tratamento de dados com o objetivo de analisar o atraso no pagamento de aluguéis no condomínio fictício de alguns moradores.

# %%
dados2
# Out:
#    apartamento datas_combinadas_pagamento datas_de_pagamento  valor_aluguel
# 0        A101                  01/06/2022         05/06/2022         1000.0
# 1        A101                  01/07/2022         03/07/2022         2500.0
# 2        A102                  02/06/2022         02/06/2022         1100.0
# 3        A102                  02/07/2022         06/07/2022         2600.0
# 4        B201                  03/06/2022         07/06/2022         1200.0
# 5        B201                  03/07/2022         03/07/2022         2700.0
# 6        B202                  04/06/2022         07/06/2022         1300.0
# 7        B202                  04/07/2022         05/07/2022         2800.0
# 8        C301                  05/06/2022         10/06/2022         1400.0
# 9        C301                  05/07/2022         09/07/2022         2900.0
# 10       C302                  06/06/2022         08/06/2022         1500.0
# 11       C302                  06/07/2022         12/07/2022         1200.0
# 12       D401                  07/06/2022         07/06/2022         1600.0
# 13       D401                  07/07/2022         09/07/2022         1300.0
# 14       D402                  08/06/2022         10/06/2022         1700.0
# 15       D402                  08/07/2022         14/07/2022         1400.0
# 16       E501                  09/06/2022         10/06/2022         1800.0
# 17       E501                  09/07/2022         09/07/2022         1500.0
# 18       E502                  10/06/2022         16/06/2022         1900.0
# 19       E502                  10/07/2022         12/07/2022         1600.0
# 20       F601                  11/06/2022         17/06/2022         2000.0
# 21       F601                  11/07/2022         13/07/2022         1000.0
# 22       F602                  12/06/2022         15/06/2022         2100.0
# 23       F602                  12/07/2022         12/07/2022         1100.0
# 24       G701                  13/06/2022         19/06/2022         2200.0
# 25       G701                  13/07/2022         20/07/2022         1200.0
# 26       G702                  14/06/2022         15/06/2022         2300.0
# 27       G702                  14/07/2022         17/07/2022         2100.0
# 28       H801                  15/06/2022         18/06/2022         2400.0
# 29       H801                  15/07/2022         16/07/2022         2200.0

# %%
colunas_dts = list(dados2.columns[1:3])
colunas_dts
# Out:
# ['datas_combinadas_pagamento', 'datas_de_pagamento']

# %%
dados2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 4 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   apartamento                 30 non-null     object
#  1   datas_combinadas_pagamento  30 non-null     object
#  2   datas_de_pagamento          30 non-null     object
#  3   valor_aluguel               30 non-null     float64
# dtypes: float64(1), object(3)
# memory usage: 1.1+ KB

# %%
dados2[['datas_combinadas_pagamento', 'datas_de_pagamento']] = dados2[['datas_combinadas_pagamento', 'datas_de_pagamento']].apply(lambda x: pd.to_datetime(x, format='%d/%m/%Y'))

# %%
dados2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 4 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   apartamento                 30 non-null     object
#  1   datas_combinadas_pagamento  30 non-null     datetime64[ns]
#  2   datas_de_pagamento          30 non-null     datetime64[ns]
#  3   valor_aluguel               30 non-null     float64
# dtypes: datetime64[ns](2), float64(1), object(1)
# memory usage: 1.1+ KB

# %%
#dados_agrupados = dados_agrupados.assign(emissao_per_capita = dados_agrupados['Emissão']/dados_agrupados['populacao']).sort_values('emissao_per_capita', ascending = False)
dados_atualizados = dados2.assign(dias_atraso_aluguel = dados2['datas_de_pagamento'] - dados2['datas_combinadas_pagamento'])
dados_atualizados
# Out:
#    apartamento datas_combinadas_pagamento datas_de_pagamento  valor_aluguel  \
# 0        A101                  2022-06-01         2022-06-05         1000.0
# 1        A101                  2022-07-01         2022-07-03         2500.0
# 2        A102                  2022-06-02         2022-06-02         1100.0
# 3        A102                  2022-07-02         2022-07-06         2600.0
# 4        B201                  2022-06-03         2022-06-07         1200.0
# 5        B201                  2022-07-03         2022-07-03         2700.0
# 6        B202                  2022-06-04         2022-06-07         1300.0
# 7        B202                  2022-07-04         2022-07-05         2800.0
# 8        C301                  2022-06-05         2022-06-10         1400.0
# 9        C301                  2022-07-05         2022-07-09         2900.0
# 10       C302                  2022-06-06         2022-06-08         1500.0
# 11       C302                  2022-07-06         2022-07-12         1200.0
# 12       D401                  2022-06-07         2022-06-07         1600.0
# 13       D401                  2022-07-07         2022-07-09         1300.0
# 14       D402                  2022-06-08         2022-06-10         1700.0
# 15       D402                  2022-07-08         2022-07-14         1400.0
# 16       E501                  2022-06-09         2022-06-10         1800.0
# 17       E501                  2022-07-09         2022-07-09         1500.0
# 18       E502                  2022-06-10         2022-06-16         1900.0
# 19       E502                  2022-07-10         2022-07-12         1600.0
# 20       F601                  2022-06-11         2022-06-17         2000.0
# 21       F601                  2022-07-11         2022-07-13         1000.0
# 22       F602                  2022-06-12         2022-06-15         2100.0
# 23       F602                  2022-07-12         2022-07-12         1100.0
# 24       G701                  2022-06-13         2022-06-19         2200.0
# 25       G701                  2022-07-13         2022-07-20         1200.0
# 26       G702                  2022-06-14         2022-06-15         2300.0
# 27       G702                  2022-07-14         2022-07-17         2100.0
# 28       H801                  2022-06-15         2022-06-18         2400.0
# 29       H801                  2022-07-15         2022-07-16         2200.0
#
#    dias_atraso_aluguel
# 0               4 days
# 1               2 days
# 2               0 days
# 3               4 days
# 4               4 days
# 5               0 days
# 6               3 days
# 7               1 days
# 8               5 days
# 9               4 days
# 10              2 days
# 11              6 days
# 12              0 days
# 13              2 days
# 14              2 days
# 15              6 days
# 16              1 days
# 17              0 days
# 18              6 days
# 19              2 days
# 20              6 days
# 21              2 days
# 22              3 days
# 23              0 days
# 24              6 days
# 25              7 days
# 26              1 days
# 27              3 days
# 28              3 days
# 29              1 days

# %%
subset2 = dados_atualizados.groupby('apartamento')['dias_atraso_aluguel'].sum().sort_values(ascending=False)
subset2 = subset2.to_frame()
subset2
# Out:
#             dias_atraso_aluguel
# apartamento
# G701                    13 days
# C301                     9 days
# C302                     8 days
# D402                     8 days
# E502                     8 days
# F601                     8 days
# A101                     6 days
# A102                     4 days
# B201                     4 days
# B202                     4 days
# G702                     4 days
# H801                     4 days
# F602                     3 days
# D401                     2 days
# E501                     1 days

# %%
subset2.plot(kind='barh', figsize=(10,6), xlabel='dias_atraso_aluguel')
# Out:
# <Axes: xlabel='dias_atraso_aluguel', ylabel='apartamento'>

# %%
apartamento_com_maior_atraso = subset2.reset_index()
#cliente_maior_compra = dados.loc[(dados['Data de venda'] >= dados['Data de venda'].min()) & (dados['Data de venda'] <= dados['Data de venda'].max())].groupby('Cliente')['Valor da compra'].sum()
apartamento_com_maior_atraso
# Out:
#    apartamento dias_atraso_aluguel
# 0        G701              13 days
# 1        C301               9 days
# 2        C302               8 days
# 3        D402               8 days
# 4        E502               8 days
# 5        F601               8 days
# 6        A101               6 days
# 7        A102               4 days
# 8        B201               4 days
# 9        B202               4 days
# 10       G702               4 days
# 11       H801               4 days
# 12       F602               3 days
# 13       D401               2 days
# 14       E501               1 days

# %%
apartamento_com_maior_atraso = apartamento_com_maior_atraso.groupby('apartamento')['dias_atraso_aluguel'].max()
apartamento_com_maior_atraso = apartamento_com_maior_atraso.idxmax()
print(f'O apartamento com maior quantidade de dias atrasados para pagamento do aluguel é o {apartamento_com_maior_atraso}')
# Out:
# O apartamento com maior quantidade de dias atrasados para pagamento do aluguel é o G701
